# %%
#I am using the faang stocks to learn machine learning. This notebook is for it.
#https://www.kaggle.com/datasets/parisrohan/faang-stocks-covid190101202004012022

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/faang-stocks-covid190101202004012022/faang_stocks_pandemic_data.csv

# %%
#load the dataset, see if its loaded correctly
df = pd.read_csv (r'../input/faang-stocks-covid190101202004012022/faang_stocks_pandemic_data.csv')
print (df)
# Out:
#       Unnamed: 0        Date         High          Low         Open  \
# 0            683  2020-01-02   209.789993   206.270004   206.750000
# 1            684  2020-01-03   210.399994   206.949997   207.210007
# 2            685  2020-01-06   212.779999   206.520004   206.699997
# 3            686  2020-01-07   214.580002   211.750000   212.820007
# 4            687  2020-01-08   216.240005   212.610001   213.000000
# ...          ...         ...          ...          ...          ...
# 2835        1246  2022-03-28  2840.050049  2796.229980  2818.010010
# 2836        1247  2022-03-29  2875.870117  2840.770020  2852.949951
# 2837        1248  2022-03-30  2854.409912  2832.000000  2849.199951
# 2838        1249  2022-03-31  2842.159912  2780.489990  2841.060059
# 2839        1250  2022-04-01  2809.419922  2766.149902  2790.000000
#
#             Close      Volume    Adj Close      Name
# 0      209.779999  12077100.0   209.779999  Facebook
# ...

# %%
#find the count of null data fields
df.isnull().sum()
print (df)
#remove unnamed columns
df.drop(columns= ['Unnamed: 0'], axis = 1 ,inplace=True)
df.head()

df.shape
df.columns
#find the stock that had the hightest closing price
#load the row of that stock
print (df)
# Out:
#       Unnamed: 0        Date         High          Low         Open  \
# 0            683  2020-01-02   209.789993   206.270004   206.750000
# 1            684  2020-01-03   210.399994   206.949997   207.210007
# 2            685  2020-01-06   212.779999   206.520004   206.699997
# 3            686  2020-01-07   214.580002   211.750000   212.820007
# 4            687  2020-01-08   216.240005   212.610001   213.000000
# ...          ...         ...          ...          ...          ...
# 2835        1246  2022-03-28  2840.050049  2796.229980  2818.010010
# 2836        1247  2022-03-29  2875.870117  2840.770020  2852.949951
# 2837        1248  2022-03-30  2854.409912  2832.000000  2849.199951
# 2838        1249  2022-03-31  2842.159912  2780.489990  2841.060059
# 2839        1250  2022-04-01  2809.419922  2766.149902  2790.000000
#
#             Close      Volume    Adj Close      Name
# 0      209.779999  12077100.0   209.779999  Facebook
# ...

# %%
#Stock with the highest,lowest closing price on any given day

#find max in all columns
#print(df.max())
#find the index of the max value in the Close column
maxVal = (df['Close']. idxmax())
#print(maxIndex)
print(df.iloc[maxVal])
#find number of max values in a column, the below print line prints only the column info. Doesnt print actual rows. Check this later
#print((df.loc[df['Close'] == maxVal]))
#print all max rows
# Out:
# Date          2021-07-08
# High          3759.98999
# Low          3621.120117
# Open         3643.560059
# Close        3731.409912
# Volume         5180600.0
# Adj Close    3731.409912
# Name              Amazon
# Name: 949, dtype: object

# %%
#find min in all columns
#print(df.min())
#find the index of the min value in the Close column
minIndex = (df['Close']. idxmin())
#print(minIndex)
print(df.iloc[minIndex])
#find number of min values in a column

#print all min rows
# Out:
# Date          2020-03-23
# High              57.125
# Low              53.1525
# Open               57.02
# Close          56.092499
# Volume       336752800.0
# Adj Close      55.332169
# Name               Apple
# Name: 1191, dtype: object

# %%
#find all unique Name(stocks) in the df
stockNames = (df['Name'].unique())
print(stockNames)

#print all Facebook columns
print((df.loc[df['Name'] == 'Facebook']))
#The stock with the best return by the end of the year, it means it had the highest return value among all stocks.
#df[""] = df[["A", "B"]].max(axis=1)
# Out:
# ['Facebook' 'Amazon' 'Apple' 'Netflix' 'Google']
#            Date        High         Low        Open       Close      Volume  \
# 0    2020-01-02  209.789993  206.270004  206.750000  209.779999  12077100.0
# 1    2020-01-03  210.399994  206.949997  207.210007  208.669998  11188400.0
# 2    2020-01-06  212.779999  206.520004  206.699997  212.600006  17058900.0
# 3    2020-01-07  214.580002  211.750000  212.820007  213.059998  14912400.0
# 4    2020-01-08  216.240005  212.610001  213.000000  215.220001  13475000.0
# ..          ...         ...         ...         ...         ...         ...
# 563  2022-03-28  224.039993  219.539993  222.130005  223.589996  26224100.0
# 564  2022-03-29  230.889999  225.289993  226.070007  229.860001  31417900.0
# 565  2022-03-30  231.149994  226.710007  228.910004  227.850006  25588000.0
# 566  2022-03-31  228.490005  222.259995  228.449997  222.360001  24192300.0
# 567  2022-04-01  227.279999  222.699997  224.550003  224.850006  19533300.0
#
# ...
